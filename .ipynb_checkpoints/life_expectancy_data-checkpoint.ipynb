# %% [markdown]
# # Life Expectancy in the World - Data Analysis

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import folium
import pycountry_convert as pc

sns.set_theme(style="whitegrid")
df = pd.read_csv('data/LifeExpectancy.csv')
df.columns
# Out:
# Index(['Country', 'Year', 'Status', 'Life expectancy', 'Adult Mortality',
#        'infant deaths', 'Alcohol', 'percentage expenditure', 'Hepatitis B',
#        'Measles ', ' BMI ', 'under-five deaths ', 'Polio', 'Total expenditure',
#        'Diphtheria ', ' HIV/AIDS', 'GDP', 'Population',
#        ' thinness  1-19 years', ' thinness 5-9 years',
#        'Income composition of resources', 'Schooling'],
#       dtype='object')

# %% [markdown]
# ## Adjusting Dataset

# %%
df['Country'] = df['Country'].str.replace(r"\s*\(.*?\)", "", regex=True)
replace_dict = {'Republic of Korea': 'South Korea', 
               'The former Yugoslav republic of Macedonia': 'North Macedonia'}
df['Country'] = df['Country'].replace(replace_dict)

# Add continent
def get_continent(country_name):
    try:
        if country_name == "Timor-Leste":
            return "Asia"
        # Convert country name to alpha-2 ISO code
        country_code = pc.country_name_to_country_alpha2(country_name)
        # Get continent code from alpha-2 code
        continent_code = pc.country_alpha2_to_continent_code(country_code)
        # Map continent code to continent name
        continent_map = {
            'AF': 'Africa',
            'AS': 'Asia',
            'EU': 'Europe',
            'NA': 'North America',
            'SA': 'South America',
            'OC': 'Oceania',
            'AN': 'Antarctica'
        }
        return continent_map.get(continent_code, 'Unknown')
    except KeyError:
        return 'Unknown'

# Apply the function to add a new column
df['Continent'] = df['Country'].apply(get_continent)

# %% [markdown]
# ## Features over time

# %%
def get_data_per_continent_year(df, param):
    data = []
    years = df['Year'].unique()
    for c in df['Continent'].unique():
        continent_data = df[df['Continent']==c]
        plt.plot(years, continent_data.groupby('Year')[param].mean())
        plt.scatter(years, continent_data.groupby('Year')[param].mean(), label=c)

# change param to visualize other data
param = ['Schooling', 'GDP', 'Total expenditure'] 

for p in param:
    plt.figure(figsize=(8,4))
    continents = get_data_per_continent_year(df, p)
    plt.title(p)
    plt.legend(loc='upper left', bbox_to_anchor=(1, 1))
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## Pie Charts - Population, Infant Deaths, Measles

# %%
start_year = df['Year'].unique().min()
end_year = df['Year'].unique().max()

def get_data_per_continent(df, param):
    data = []
    for c in df['Continent'].unique():
        continent_data = df[df['Continent']==c][param]
        data.append(continent_data.sum())
    return data

params = [ 'Population', 'infant deaths', 'Measles ']

param0 = get_data_per_continent(df, params[0])
param1 = get_data_per_continent(df, params[1])
param2 = get_data_per_continent(df, params[2])

# Set up subplots for 3 pie charts
fig, axes = plt.subplots(1, 3, figsize=(18, 6))

# List of parameter data for the plots
param_data = [param0, param1, param2]

# Create pie charts
for i, ax in enumerate(axes):
    ax.pie(param_data[i], labels=df['Continent'].unique(), autopct='%1.1f%%', 
           startangle=140, colors=plt.cm.tab20.colors)
    ax.set_title(f'{params[i].upper()} per Continent\n({start_year}-{end_year})', fontsize=20)

# Adjust layout
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Visualize Data on World Map

# %%
# Create a base map
def make_map(data, column):
    m = folium.Map(location=[0, 0], zoom_start=2)
    
    # Add the choropleth layer
    folium.Choropleth(
        geo_data='https://raw.githubusercontent.com/johan/world.geo.json/master/countries.geo.json',  # GeoJSON file
        name='choropleth',
        data=data,
        columns=['Country', column],
        key_on='feature.properties.name',  # Match GeoJSON properties to your 'country' column
        fill_color='YlGnBu',
        fill_opacity=0.7,
        line_opacity=0.2,
        nan_fill_color="lightgrey"
    ).add_to(m)
    
    # Add layer control
    folium.LayerControl().add_to(m)
    
    # Save or display the map
    m.save('life_expectancy_map.html')
    return m

# %% [markdown]
# ## Life Expectancy per Country

# %%
make_map(df, 'Life expectancy')
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_27da6cedd903eb4ee3cafe1d6e4430a0 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_27da6cedd903eb4ee3cafe1d6e4430a0&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_27da6cedd903eb4ee3cafe1d6e4430a0 = L.map(
#                 &quot;map_27da6cedd903eb4ee3cafe1d6e4430a0&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 2,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e6dc1e12bcd2c26edec7f62e8f6ab514 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_e6dc1e12bcd2c26edec7f62e8f6ab514.addTo(map_27da6cedd903eb4ee3cafe1d6e4430a0);
#
#
#             var choropleth_2211f959a81af9829217dba835004765 = L.featureGroup(
#                 {}
#             );
#
#
#         function geo_json_76d7a260af6d1223b146cfe9fdcd359e_styler(feature) {
#             switch(feature.properties.name) {
#                 case &quot;Afghanistan&quot;: case &quot;Burundi&quot;: case &quot;Benin&quot;: case &quot;Djibouti&quot;: case &quot;Ghana&quot;: case &quot;Gambia&quot;: case &quot;Haiti&quot;: case &quot;Cambodia&quot;: case &quot;Madagascar&quot;: case &quot;Mauritania&quot;: case &quot;Namibia&quot;: case &quot;Papua New Guinea&quot;: case &quot;Sudan&quot;: case &quot;Senegal&quot;: case &quot;Somalia&quot;: case &quot;Togo&quot;: case &quot;South Africa&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#7fcdbb&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case &quot;Angola&quot;: case &quot;Central African Republic&quot;: case &quot;Eritrea&quot;: case &quot;Malawi&quot;: case &quot;Sierra Leone&quot;: case &quot;Zambia&quot;: case &quot;Zimbabwe&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#ffffcc&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case &quot;Albania&quot;: case &quot;Armenia&quot;: case &quot;Bulgaria&quot;: case &quot;Belarus&quot;: case &quot;Belize&quot;: case &quot;China&quot;: case &quot;Colombia&quot;: case &quot;Dominican Republic&quot;: case &quot;Algeria&quot;: case &quot;Ecuador&quot;: case &quot;Egypt&quot;: case &quot;Fiji&quot;: case &quot;Georgia&quot;: case &quot;Guatemala&quot;: case &quot;Honduras&quot;: case &quot;Hungary&quot;: case &quot;Iran&quot;: case &quot;Iraq&quot;: case &quot;Jamaica&quot;: case &quot;Jordan&quot;: case &quot;Kuwait&quot;: case &quot;Lebanon&quot;: case &quot;Sri Lanka&quot;: case &quot;Lithuania&quot;: case &quot;Latvia&quot;: case &quot;Morocco&quot;: case &quot;Montenegro&quot;: case &quot;Malaysia&quot;: case &quot;Nicaragua&quot;: case &quot;Oman&quot;: case &quot;Peru&quot;: case &quot;Poland&quot;: case &quot;Saudi Arabia&quot;: case &quot;El Salvador&quot;: case &quot;Suriname&quot;: case &quot;Slovakia&quot;: case &quot;Thailand&quot;: case &quot;Trinidad and Tobago&quot;: case &quot;Tunisia&quot;: case &quot;Turkey&quot;: case &quot;Ukraine&quot;: case &quot;Uzbekistan&quot;: case &quot;Venezuela&quot;: case &quot;Vanuatu&quot;: case &quot;Yemen&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#2c7fb8&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case &quot;Antarctica&quot;: case &quot;French Southern and Antarctic Lands&quot;: case &quot;The Bahamas&quot;: case &quot;Bermuda&quot;: case &quot;Brunei&quot;: case &quot;Ivory Coast&quot;: case &quot;Republic of the Congo&quot;: case &quot;Northern Cyprus&quot;: case &quot;Czech Republic&quot;: case &quot;Falkland Islands&quot;: case &quot;United Kingdom&quot;: case &quot;Guinea Bissau&quot;: case &quot;Greenland&quot;: case &quot;French Guiana&quot;: case &quot;Kosovo&quot;: case &quot;Laos&quot;: case &quot;Moldova&quot;: case &quot;Macedonia&quot;: case &quot;New Caledonia&quot;: case &quot;Puerto Rico&quot;: case &quot;North Korea&quot;: case &quot;Russia&quot;: case &quot;Western Sahara&quot;: case &quot;Somaliland&quot;: case &quot;Republic of Serbia&quot;: case &quot;Syria&quot;: case &quot;East Timor&quot;: case &quot;Taiwan&quot;: case &quot;Vietnam&quot;: case &quot;West Bank&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;lightgrey&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case &quot;Azerbaijan&quot;: case &quot;Bangladesh&quot;: case &quot;Bolivia&quot;: case &quot;Bhutan&quot;: case &quot;Gabon&quot;: case &quot;Guyana&quot;: case &quot;Indonesia&quot;: ca
